# %% [markdown]
# # Análise Dados Base Genética

# %% [markdown]
# ## 1. Importando as Bibliotecas

# %%
import pandas as pd
# %reload_kedro /home/robson/rep/classificador_variacoes_geneticas
# %load_ext kedro.extras.extensions.ipython
# Out:
# [09/05/22 23:39:28] INFO     Updated path to Kedro project:                                           ]8;id=385391;file:///home/robson/rep/classificador_variacoes_geneticas/env/lib/python3.9/site-packages/kedro/extras/extensions/ipython.py\ipython.py]8;;\:]8;id=60714;file:///home/robson/rep/classificador_variacoes_geneticas/env/lib/python3.9/site-packages/kedro/extras/extensions/ipython.py#53\53]8;;\
#                              /home/robson/rep/classificador_variacoes_geneticas
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /home/robson/rep/classificador_variacoes_geneticas/env/lib/python3.9/site-packages/kedro/io/core │
# │ .py:155 in from_config                                                                           │
# │                                                                                                  │
# ...

# %%
catalog.list()
# Out:
# ['parameters']

# %%
training_text = pd.read_csv('/home/robson/rep/classificador_variacoes_geneticas/data/01_raw/training_text', sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)

# %%
training_variants =pd.read_csv('/home/robson/rep/classificador_variacoes_geneticas/data/01_raw/training_variants')

# %%
training_variants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3321 entries, 0 to 3320
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         3321 non-null   int64
#  1   Gene       3321 non-null   object
#  2   Variation  3321 non-null   object
#  3   Class      3321 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 103.9+ KB
